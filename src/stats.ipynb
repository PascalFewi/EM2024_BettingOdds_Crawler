# %%
import os
import pandas as pd

# %%
directory = 'odds'
dataframes = []

for filename in os.listdir(directory):
    df = pd.read_csv(os.path.join(directory, filename))
    df['Filename'] = (filename[:-4])[5:]
    dataframes.append(df)

combined_df = pd.concat(dataframes, ignore_index=True)

# %%
combined_df
# Out:
#      Unnamed: 0                      Game Title Result  Odds    Filename
# 0             0              Spanien – Kroatien    1:0  5.70  11_06_2024
# 1             1              Spanien – Kroatien    2:0  6.99  11_06_2024
# 2            13              Spanien – Kroatien    1:1  5.50  11_06_2024
# 3            29        Deutschland – Schottland    1:0  5.84  11_06_2024
# 4            30        Deutschland – Schottland    2:0  5.11  11_06_2024
# ..          ...                             ...    ...   ...         ...
# 103         999  Tschechische Republik – Türkei    1:1  5.13  11_06_2024
# 104        1002  Tschechische Republik – Türkei    0:1  7.38  11_06_2024
# 105        1028            Slowenien – Dänemark    1:1  5.67  11_06_2024
# 106        1031            Slowenien – Dänemark    0:1  5.17  11_06_2024
# 107        1032            Slowenien – Dänemark    0:2  6.29  11_06_2024
#
# [108 rows x 5 columns]
